# %%
import pymysql.cursors
import pandas as pd
import numpy as np
import re
import math

# %%
def connect_to_database(db="UltimateGuitarTabs"):
    """
    Connects to MySQL database and 
    returns the connection"""
    db = pymysql.connect(host="localhost",  # your host 
                         user="root",       # username
                         passwd="",     # password
                         db=db)   # name of the database
    return db

def print_table(tableName):
    """
    Prints database table
    """
    db = connect_to_database()
    cur = db.cursor()

    # Select data from table using SQL query.
    cur.execute("SELECT * FROM "+tableName)
    # print the first and second columns      
    for row in cur.fetchall() :
        print(row)
        
def get_table(tableName):
    db = connect_to_database()
    cur = db.cursor()

    # Select data from table using SQL query.
    cur.execute("SELECT * FROM "+tableName)
    
    return(cur.fetchall())

# %%
Chords = pd.DataFrame(list(get_table('Chords')), columns=['id','Song', 'Artist', 'Key', 'Capo', 'Chords'])
Chords
# Out:
#           id                               Song                    Artist  \
# 0         23     Beer Drinkers And Hell Raisers                    ZZ Top
# 1         73                       Harvest Moon                Neil Young
# 2         74                          Unplugged                Neil Young
# 3        105                     Ball And Chain                       XTC
# 4        118                        Los Angeles                         X
# 5        120                    The Hungry Wolf                         X
# 6        234                     Roses Are Free                      Ween
# 7        300                             Angels           Robbie Williams
# 8        407                     The Difference           The Wallflowers
# 9        464               I Lay My Love On You                  Westlife
# 10       835                With Or Without You                        U2
# 11      1345                Youre Still The One              Shania Twain
# 12      1406                             Jumper           Third Eye Blind
# 13      1433                   Drops Of Jupiter                     Train
# 14      2707                            Kiss Me  Sixpence None the Richer
# 15      3391                  Grow Old With You              Adam Sandler
# 16      4017                        Wild Horses        The Rolling Stones
# 17      4019  You Cant Always Get What You Want        The Rolling Stones
# 18      4149                 Fake Plastic Trees                 Radiohead
# 19      4169                              Creep                 Radiohead
# 20      5655                        Free Fallin                 Tom Petty
# 21      5847                          One Of Us              Joan Osborne
# 22      6091                Champagne Supernova                     Oasis
# 23      6097            Dont Look Back In Anger                     Oasis
# 24      6124                           Whatever                     Oasis
# 25      6125                         Wonderwall                     Oasis
# 26      7560                 California Dreamin     The Mamas & The Papas
# 27      8802               Nothing Else Matters                 Metallica
# 28      9306                            Imagine               John Lennon
# 29      9324                        Jealous Guy               John Lennon
# ..       ...                                ...                       ...
# 907  1861929                    Let Me Love You                  DJ Snake
# 908  1863305                            Fix You                  Coldplay
# 909  1863781                             Closer          The Chainsmokers
# 910  1865744                             Closer          The Chainsmokers
# 911  1868114                              Mercy              Shawn Mendes
# 912  1874664                Say You Wont Let Go              James Arthur
# 913  1874747                Say You Wont Let Go              James Arthur
# 914  1879128                          This Town               Niall Horan
# 915  1884102                    Million Reasons                 Lady Gaga
# 916  1900941               Versace On The Floor                Bruno Mars
# 917  1901019               Versace On The Floor                Bruno Mars
# 918  1905507                     How Far Ill Go              Alessia Cara
# 919  1928431                       Shape Of You                Ed Sheeran
# 920  1928433                 Castle On The Hill                Ed Sheeran
# 921  1928439                       Shape Of You                Ed Sheeran
# 922  1932541                          Despacito                Luis Fonsi
# 923  1937161                             Issues            Julia Michaels
# 924  1941491                           Believer           Imagine Dragons
# 925  1953009           Something Just Like This          The Chainsmokers
# 926  1956585                            Happier                Ed Sheeran
# 927  1956589                            Perfect                Ed Sheeran
# 928  1956593                        Galway Girl                Ed Sheeran
# 929  1956603                Supermarket Flowers                Ed Sheeran
# 930  1956685                               Dive                Ed Sheeran
# 931  1977189                  Sign Of The Times              Harry Styles
# 932  1983837      Theres Nothing Holdin Me Back              Shawn Mendes
# 933  1986333                          Attention              Charlie Puth
# 934  2062935                          Despacito                Luis Fonsi
# 935  2105155                             Havana            Camila Cabello
# 936  2142281               Too Good At Goodbyes                 Sam Smith
#
#      Key  Capo                                             Chords
# 0            0  Em7,E,D,A5,A6,B5,B6,Em7,Em7,E,D,A5,A6,A5,A6,Em...
# 1            0  G,C,C,G,C,G,C,C,G,C,G,C,C,G,C,G,C,G,G,Bm,C,Am,...
# 2            0  G,C,G,G,C,G,C,G,C,G,D,C,G,G,C,G,G,C,G,C,C,Am,C...
# 3            0  C,C7sus4,C,C7sus4,C,C7sus4,Bb,F,C,G5,D,F,C,G5,...
# 4            0  E,C,D,G,A,A,G,D,C,A,G,D,C,A,G,C,A,G,C,A,G,C,A,...
# 5            0  C,B,B,C,B,C,B,D,E,C,B,C,B,C,B,D,E,E,C,E,C,B,C,...
# 6            0                                        F,G,G#,A,A#
# 7            0  E,E,A,C#m,B,E,A,C#m,B,A,C#m,A,D,A,E,D,A,E,B,C#...
# 8            0  E,A,E,A,B,E,C#,B,E,A,E,A,B,E,C#,B,E,A,E,A,B,E,...
# 9            0  Am,Dm,G,C,Em,Am,Dm,F,G,C,G,Am,Dm,G,C,Em,Am,Dm,...
# 10     D     0  D,A,Bm,G,D,A,Bm,G,D,A,Bm,G,D,A,Bm,G,D,A,Bm,G,D...
# 11    Eb     1  D,D,G,A,D,G,A,D,G,A,D,G,A,D,G,A,D,G,A,D,G,Em,A...
# 12           0       Fmaj7,C,G,Am,D11,Fmaj7,C,G,Am,C,G,Am,D11,C,G
# 13     C     0  C,G,F,C,G,F,C,G,F,G,D,F,C,G,D,Dm,F,C,G,F,C,G,F...
# 14     D     1  D,Dmaj7,D7,Dmaj7,D,Dmaj7,D7,Dmaj7,D,Dmaj7,D7,G...
# 15     A     0  A,Bm,C#m,D,A,E,D,A,E,A,Bm,C#m,D,A,E,D,A,A7,D,A...
# 16     C     0  Bm,G,Bm,G,Am,C,D,G,D,C,Bm,G,Bm,G,Am,C,D,G,D,Am...
# 17           0  G,Gadd9,C,A,D,G,Gadd9,G,C,G,Gadd9,G,C,G,Gadd9,...
# 18           0  A,A,F#m,D,A,D,A,F#m,D,A,D,Bm,A,Bm,A,A,F#m,D,A,...
# 19     G     0  G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G...
# 20     A     0  A,D,D,A,E,A,A,D,D,A,E,A,D,D,A,E,A,D,D,A,E,A,D,...
# 21           2  Em,Cadd9,G,D,Em,Cadd9,G,D,Em,C,G,D,Em,Cadd9,G,...
# 22     A     0  Asus2,Asus2/F#,A,G,D/F#,E,G,A,D,F,Asus2,Asus2/...
# 23     C     0  C,F,C,F,C,G,Am,E,F,G,C,Am,G,C,G,Am,E,F,G,C,Am,...
# 24           0  G,G,G,G,Dsus4/F#,E,Em7,Dsus4,Cadd9,A7sus4,A2,B...
# 25     D     0  F#m,A,Esus4,B,F#m,A,Esus4,B,F#m,A,Esus4,B,F#m,...
# 26           0  Am,E7sus4,Am,F,G,E7sus4,E7,F,C,E7,Am,F,E7sus4,...
# 27    Em     0  Em7,D,Cadd9,Em7,D,Cadd9,Em7,D,Cadd9,G,B,Em7,Em...
# 28     C     0  C,Cmaj7,F,Cadd9,Cadd9,Cmaj7,F,Cadd9,C,Cmaj7,F,...
# 29           0  G,Em,D,D7,Em,G,Em,D,D6,D7,Em,Em7,Em6,D,Dsus4,D...
# ..   ...   ...                                                ...
# 907   Am     3  Am,C,F,Am,C,F,Am,C,Em,F,Em,F,Am,C,Em,F,Em,F,F,...
# 908    C     3  C,Em,Am7,G,C,Em,Am7,G,C,Em,Am7,G,C,Em,Am7,G,C,...
# 909    C     0  Cadd9,D,Em7,D,Cadd9,D,Em7,D,Cadd9,D,Em7,D,Cadd...
# 910    C     1  C,D,Em,D,C,D,Em,D,C,D,Em,D,C,D,Em,D,C,D,Em,D,C...
# 911   Em     0  Em,G,Bm,A,Em,G,Bm,A,Em,G,Bm,A,Em,G,Bm,A,Em,G,B...
# 912    G     3  G,Dsus4,Em,C,G,Dsus4,Em,C,G,Dsus4,Em,C,G,Dsus4...
# 913    G     3  G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G...
# 914    C     2  G,Em,Cmaj7,C,G,Em,Cmaj7,C,D,Am7,D,G,D/F#,Em,Am...
# 915    C     0  C,Am,F,G,C,Am,F,Fsus2,G,G,C,Am,F,Fsus2,G,G,F,C...
# 916    G     2  C,Em,F,G,C,Em,F,G,Bb6,A,F,Fm,Dm,Am,G,F,Gm7,C,F...
# 917    D     0  D,F#m7,Gmaj7,A6,D,F#m7,Gmaj7,Bm7,A,Am7,B,Gmaj7...
# 918    C     4  C,F,Dm7,Am,G,Fm,Cmaj7,C,F,C,Dm7,Am,F,C,Dm7,Am,...
# 919  C#m     0  C#m,F#m,A,B,C#m,F#m,A,B,C#m,F#m,A,B,C#m,F#m,A,...
# 920    D     0  D,G,D,Bm,D/F#,A,D/F#,G,G,D,G,D,Bm,Bm,A7sus4,A,...
# 921  C#m     2  Bm,Em,G,A,Bm,Em,G,A,Bm,Em,G,A,Bm,Em,G,A,Bm,Em,...
# 922   Bm     0  Bm,G,D,A,Bm,G,D,A,Bm,G,D,A,Bm,G,D,A,Bm,G,D,A,B...
# 923    C     1  C,D,G,Em,C,D,G,Em,C,D,G,Em,C,D,G,Em,C,D,G,Em,C...
# 924  Bbm     1  Am,F,E,Am,F,E,Am,F,E,Am,F,E,Am,F,E,Am,F,E,Am,F...
# 925    G     0  G,A,Bm,D/F#,G,A,Bm,A,G,A,Bm,A,G,A,Bm,A,G,A,Bm,...
# 926   Am     0  Am7,F,C,Am7,F,C,Am7,F,C,Am7,F,C,Am7,F,C,Am7,F,...
# 927   Ab     1  G,G,Em,C,D,G,Em,C,D,G,Em,C,G,D,G,Em,C,D,Em,C,G...
# 928   Em     2  Em,G,D,Cadd9,Cadd9,G,D,Em,G,D,C,Em,G,D,G,Em,G,...
# 929    C     6  C,Dm,Em,F,F,C,Am,G,G,Dm7,C,Em,F,C,Em,F,C,Em,F,...
# 930    C     4  C,C,Am,F,G,C,Am,F,G,C,Am,F,F,Am,Em,F,F,Am,G,C,...
# 931    F     0  F,C,C7,Bb,C,Am,G,G7,F,F,Dm,C,F,Dm,C,F,Dm,C,F,D...
# 932    D     0  G,Bm,A,D,G,Bm,A,G,D,Bm,D,A,D,A,D,G,D,Bm,D,A,D,...
# 933   Dm     1  Dm,C,Am,A#,Dm,C,Am,A#,Dm,C,Am,A#,Dm,C,Am,A#,Dm...
# 934  Abm     7  Em,C,G,D,Em,Em,C,G,D,Em,Em,Em,C,G,D,Em,C,G,D,E...
# 935   Em     3  Em,C,B7,Em,C,B7,Em,C,B7,Em,C,B7,Em,C,B7,Em,Em,...
# 936   Dm     5  Am,C,G,Dm,Am,C,G,Dm,Am,C,G,Dm,Am,C,G,Dm,Am,C,G...
#
# [937 rows x 6 columns]

# %%
def fix_accidental(note, accidental):
    notes = np.asarray(['A', 'B', 'C', 'D', 'E', 'F', 'G'])

    note_idx = int(np.where(notes == note)[0])
    if accidental == '#':
        # Account for B# or E#
        if note == 'B':
            return('C', '')
        elif note == 'E':
            return('F', '')
        return(note,accidental)
    elif accidental == 'b':
        # Account for Cb or Fb
        if note == 'C':
            return('B', '')
        elif note == 'F':
            return('E', '')
        return(notes[note_idx - 1],'#')
    else:
        return(note, accidental)
            
        
def clean_chords(chords):
    """
    This function takes in a comma-separated string of 
    chords and cleans it by removing any base note variations, or
    other chord embelishments.  Diminished labels are kept as these
    are used in the chord progression table. The purpose of this
    is to clean the chords to match the labels within the chord
    progression table.
    
    returns:
        new_chords - array of newly cleaned chords to be tabulated
                        by the chord progression table
    """
    
    # Pattern grouping: 1=(chord pitch) 2=(base note) 3=(chord type) 4=(base note)
    pattern = "^([A-G]+)(\/[A-G]*[b#])*([(?m)|(?m\d)|(?b\d)|(?#\d)|(?maj\d)|\
    (?add\d)|(?sus\d)|(?aug)|(?aug\d)|(?dim)|(?dim\d)]*)(\/[A-G]*[b#])*"        
    prog = re.compile(pattern)

    pattern2 = "^([A-G])([b#])?(m$|m\d$)?(dim$|dim\d$)?"
    prog2 = re.compile(pattern2)

    chords = chords.split(',')
    new_chords = [""]*len(chords)
    for i in range(len(chords)):
        curr_chord = chords[i]
        groups = prog.findall(curr_chord)[0] 
        no_base = groups[0] + groups[2]
        no_num = re.sub(pattern="\d", repl="", string=no_base)

        groups = prog2.findall(no_num)[0]
        note,accidental = fix_accidental(groups[0], groups[1])
        new_chords[i] = note + accidental + groups[2] + groups[3]
        
    return(new_chords)


def get_key_tbls():
    """
    Helper function that reads in a chord progression table
    and creates a dictionary that maps chord names to their
    indices on the chord progression table. This dictionary
    will be used to tabulate a 'key table' to determine the
    key of a song.
    
    returns:
        Key_dict - Dictionary mapping chord names to indices
        Keys - array of keys that correspond to the order
                of the progression table
    """
    Key_tbl = pd.read_csv('../data/key_table.csv')
    Keys = list(Key_tbl.key)
    Tbl = np.asmatrix(Key_tbl.iloc[:,1:8])

    # Storing all possible chords 
    all_chords = []
    for i in range(Tbl.shape[0]):
        for j in np.asarray(Tbl[i])[0]:
            all_chords.append(j)
    all_chords = np.unique(all_chords)
    
    # Creating dict(key='chord', val='indices in progression tbl')
    Key_dict = {}
    for chord in all_chords:
        Key_dict[chord] = np.where(Tbl == chord)

    return(Key_dict, Keys)

def is_rel_min(comp_key, act_key):
    """
    Determines if the actual key marked indicated
    UltimateGuitarTabs.com is the relative minor
    of the actual key (i.e., Am(rel. minor) and C(actual))
    
    args:
        comp_key - Computed key
        act_key - UltimateGuitarTabs.com key
    returns:
        - True if it's relative minor, False otherwise
    """
    notes = ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']
    if str(act_key[-1]) != 'm': #If not minor, return 
        return(False)
    if len(comp_key) == 2:
        note, accidental = fix_accidental(comp_key[0],comp_key[1])
        comp_key = note + accidental
    comp_idx = np.where(np.asarray(notes) == comp_key)[0][0]
    rel_min_idx = comp_idx - 3
    if notes[rel_min_idx] + 'm' == act_key:
        return(True)

def compute_key(Key_dict, Keys, chords):
    """
    Computes the key of a song by analyzing
    the chords used within the song. A theoretical
    key matrix where each row specifies the types of chords
    that coincide with a key is used to tabulate
    the existing chords. The largest row sum is the
    computed key of the song. 
    
    args:
        Key_dict - Python dictionary containing all possible
                   chords and their indexes in the theoretical key matrix.
                   This is used to tabulate a matrix of zeros.
        Keys - List of possible keys corresponding to theoretical key matrix
        chords - String of chords separated by commas
                   
    returns:
        - The computed key
        - List of cleaned chords, only major or minor
    """
    chords = clean_chords(chords)
    count_mat = np.zeros((12,7)) # Matrix of zeros to tabulate chord occurences
    start_chord = chords[0]
    # Tabulating chords
    for chord in chords:
        count_mat[Key_dict[chord]] += 1
        
    computed_key = Keys[np.argmax(np.sum(count_mat, axis = 1))]
    return(computed_key, chords)
    
def transpose_C(Key_dict, Keys, chords, states, song_id):
    notes = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    comp_key, chords = compute_key(Key_dict, Keys, chords)
    
    new_chords = [""]*len(chords) # Empty list for new chords
    if comp_key == 'C':
        for chord in chords:
            states.add(chord)
        return(states, \
               {'song_id' : song_id, \
                'orig_key': comp_key, \
                'trans_chords': chords})
    else:
        steps = np.where(np.asarray(notes) == comp_key)[0][0]
        for i in range(len(chords)):
            is_min = False
            is_dim = False
            curr_chord = chords[i]
            if curr_chord[-1] == 'm':
                if curr_chord[-3:len(curr_chord)] == 'dim':
                    is_dim = True
                    curr_chord = curr_chord[0:-3]
                else:
                    is_min = True
                    curr_chord = curr_chord[0:-1]
            
            chord_idx = np.where(np.asarray(notes) == curr_chord)[0][0]
            new_chord_idx = chord_idx - steps
            if is_min:
                new_chords[i] = notes[new_chord_idx] + 'm'
            elif is_dim:
                new_chords[i] = notes[new_chord_idx] + 'dim'
            else:
                new_chords[i] = notes[new_chord_idx]
            states.add(new_chords[i])
        return(states, \
               {'song_id' : song_id, \
                'orig_key': comp_key, \
                'trans_chords': new_chords})
def get_songs():
    Key_dict, Keys = get_key_tbls()

    songs = [""]*Chords.shape[0]
    states = set()
    for i in range(Chords.shape[0]):
        states, songs[i] = transpose_C(Key_dict, Keys, Chords['Chords'][i], states, Chords['id'][i])
    states = sorted(list(states))
    return(states, songs)

def write_clean_songs(songs):
    db = connect_to_database()
    cur = db.cursor()
    
    delete = "DROP TABLE IF EXISTS Clean_Chords;"
    cur.execute(delete)
    
    create = "CREATE TABLE Clean_Chords (id INT(11) NOT NULL PRIMARY KEY, orig_key TEXT(5), chords TEXT(500));"
    cur.execute(create)
    
    for i in range(len(songs)):
        
        song = songs[i]
        song_id = int(song['song_id'])
        orig_key = song['orig_key']
        chords = ','.join(song['trans_chords'])
        
        sql_tab = "INSERT INTO Clean_Chords (id,orig_key,chords) \
        VALUES ('%d','%s','%s')" % \
        (song_id, orig_key, chords) 
        
        try:
            cur.execute(sql_tab)
            db.commit()
        except:
            db.rollback()

def write_states(states):
    db = connect_to_database()
    cur = db.cursor()
    delete = "DROP TABLE IF EXISTS States;"
    cur.execute(delete)
    
    create = "CREATE TABLE States (states TEXT(500));"
    cur.execute(create_tabs)
    
    sql_tab = "INSERT INTO States (states) VALUES ('%s')" % \
        ','.join(states)
    try:
        cur.execute(sql_tab)
        db.commit()
    except:
        db.rollback()

def create_transition_mat(states, chords):
    num_states = len(states)
    trans_mat = np.zeros((num_states, num_states))
    for i in range(1, len(chords)):
        curr_chord = chords[i - 1]
        curr_chord_idx = np.where(np.asarray(states) == curr_chord)[0][0]
        
        next_chord = chords[i]
        next_chord_idx = np.where(np.asarray(states) == next_chord)[0][0]
        trans_mat[curr_chord_idx, next_chord_idx] += 1

    row_sums = np.sum(trans_mat, axis = 1)
    trans_mat = trans_mat/row_sums
    return(np.nan_to_num(trans_mat))

def compute_euclidean(mat1, mat2):
    # Computes euclidean distance between two
    # transition matrices
    # NOTE: Will produce runtime warning with division by zero
    mat_dif = mat1 - mat2
    return(math.sqrt(np.sum(np.multiply(mat_dif, mat_dif)))/mat1.shape[0])

def get_similar_songs(states, song_id, clean_chords):
    curr_song = clean_chords.loc[clean_chords['id'] == song_id]
    chords = curr_song.iat[0, 2].split(',')#[0,2] As it's just one song and chords at idx 2
    tm = create_transition_mat(states,chords)
    dist = [0]*clean_chords.shape[0]
    for i in range(len(dist)):
        curr_tm = create_transition_mat(states,clean_chords['chords'][i].split(','))
        dist[i] = compute_euclidean(tm, curr_tm)
        
    dist_ord = np.argsort(dist) # Sorting by distance ascending
    
    idxs = np.unique(list(Chords['Song'][dist_ord]), return_index=True)[1] # Indexes of unique entries
    # np.unique() automatically sorts, so we must resort by distance
    sim_songs = Chords.iloc[dist_ord[sorted(idxs)]]
    return(sim_songs)

# %%
# Writing states and clean songs tables
states, songs = get_songs()
write_clean_songs(songs)
write_states(states)
# Out:
#     id         Song Artist Key  Capo  \
# 4  118  Los Angeles      X         0
#
#                                               Chords
# 4  E,C,D,G,A,A,G,D,C,A,G,D,C,A,G,C,A,G,C,A,G,C,A,...

# %%
Clean_Chords = pd.DataFrame(list(get_table('Clean_Chords')), columns=['id','orig_key', 'chords'])
states = get_table('States')[0][0].split(',')
states
Clean_Chords.loc[Clean_Chords['id'] == 118]
# Out:
#     id orig_key                                             chords
# 4  118        G  A,F,G,C,D,D,C,G,F,D,C,G,F,D,C,F,D,C,F,D,C,F,D,...

# %%
sim = get_similar_songs(states, 118, Clean_Chords)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:240: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:240: RuntimeWarning: divide by zero encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:248: RuntimeWarning: overflow encountered in multiply

# %%
sim
# Out:
#           id                                      Song                 Artist  \
# 4        118                               Los Angeles                      X
# 480   698704                        Remembering Sunday           All Time Low
# 17      4019         You Cant Always Get What You Want     The Rolling Stones
# 762  1189512                                        22           Taylor Swift
# 501   746376                                      Toes         Zac Brown Band
# 109    44578                                    Mother             Pink Floyd
# 116    47489            Where Did You Sleep Last Night                Nirvana
# 307   277200                          Joy To The World         Misc Christmas
# 517   760569                              You Found Me               The Fray
# 441   621851               You Shook Me All Night Long                  AC/DC
# 312   319116                            Johnny B Goode            Chuck Berry
# 151    63352                              Ring Of Fire            Johnny Cash
# 807  1426261                               Hey Brother                 Avicii
# 695  1093785                                     Drunk             Ed Sheeran
# 677  1068195                            Happy Birthday       Misc Traditional
# 222   118610                      All The Small Things              Blink-182
# 261   166605                        Three Little Birds             Bob Marley
# 20      5655                               Free Fallin              Tom Petty
# 156    66733                             Amazing Grace          Daniel Thomas
# 712  1114252                                 One Thing          One Direction
# 277   185173                                 New Slang              The Shins
# 536   811776                       Folsom Prison Blues            Johnny Cash
# 51     15835                           I Walk The Line            Johnny Cash
# 344   388558                       You Are My Sunshine           Kevin Devine
# 59     17403          Youve Got To Hide Your Love Away            The Beatles
# 893  1779555                          Secret Love Song             Little Mix
# 632   998588                           The Story Of Us           Taylor Swift
# 692  1092233                         Mr Tambourine Man              Bob Dylan
# 42     14299                     Peaceful Easy Feeling                 Eagles
# 139    57139  I Still Havent Found What Im Looking For                     U2
# ..       ...                                       ...                    ...
# 328   351326                           Dani California  Red Hot Chili Peppers
# 406   517579                         Man In The Mirror        Michael Jackson
# 252   157639                            Because Of You         Kelly Clarkson
# 442   627220                           Tears In Heaven           Eric Clapton
# 433   594514                                    Listen                Beyoncé
# 664  1046742                         Dont You Remember                  Adele
# 181    87063                                    Africa                   Toto
# 918  1905507                            How Far Ill Go           Alessia Cara
# 221   118222                    Officially Missing You                  Tamia
# 62     17446              While My Guitar Gently Weeps            The Beatles
# 166    77613                              About A Girl                Nirvana
# 146    60215                    What A Wonderful World        Louis Armstrong
# 482   703476                          Under The Bridge  Red Hot Chili Peppers
# 267   171361               Aladdin - A Whole New World          Misc Cartoons
# 245   145205                                   Starman            David Bowie
# 855  1514088                                      Ikaw       Yeng Constantino
# 489   724372                                     Snuff               Slipknot
# 314   327834                      Youll Be In My Heart           Phil Collins
# 133    55346                      We Are The Champions                  Queen
# 897  1785630                                 All I Ask                  Adele
# 161    71843                            Heal The World        Michael Jackson
# 537   813094                                   At Last             Etta James
# 102    40606                         Bohemian Rhapsody                  Queen
# 657  1031317                                Forget You           Cee Lo Green
# 172    80614                          Dont Stop Me Now                  Queen
# 6        234                            Roses Are Free                   Ween
# 917  1901019                      Versace On The Floor             Bruno Mars
# 64     17511                                    Always               Bon Jovi
# 120    50313                                 Your Love                 Alamid
# 666  1051336                                 Piano Man             Billy Joel
#
#     Key  Capo                                             Chords
# 4           0  E,C,D,G,A,A,G,D,C,A,G,D,C,A,G,C,A,G,C,A,G,C,A,...
# 480   A     2  Cadd9,Em,Cadd9,A7,Cadd9,Em,Cadd9,A7,Cadd9,D,Em...
# 17          0  G,Gadd9,C,A,D,G,Gadd9,G,C,G,Gadd9,G,C,G,Gadd9,...
# 762         0  G,Dsus4,Cadd9,Dsus4,G,Dsus4,Cadd9,Dsus4,G,Dsus...
# 501         2  A,D,A,E,A,D,A,E,A,A,D,A,E,D,E,A,A,D,A,E,A,D,A,...
# 109         0  G,Cadd9,G,G,Cadd9,G,Cadd9,G,D,Cadd9,Cadd9,G,G,...
# 116   E     0  E,A,G,B,E,E,A,G,B,E,E,A,G,B,E,E,A,G,B,E,E,A,G,...
# 307   G     0  G,D,G,C,D,G,G,G,G,G,G,D,D,G,C,G,D,G,G,D,G,C,D,...
# 517         0  E,B,G#m,F#,E,B,G#m,F#,B,E,E,B,G#m,F#,B,E,E,B,G...
# 441         0  G,C,D,G,C,D,G,G,C,D,G,G,C,D,D7,G,C,D,C,G,C,D,C...
# 312  Bb     0  Eb,Bb,F,Eb,Bb,F,Bb,Eb,Bb,F,Bb,Bb,Bb,Eb,Bb,F,Bb...
# 151   G     0  G,C,G,G,D,G,G,C,G,D,G,C,G,D,G,D,C,G,D,C,G,C,G,...
# 807  Gm     3  Em,Em,C,G,D,Em,Em,C,G,D,Em,D,G,C,D,D,G6,C,Em,E...
# 695         0  G,G,D/F#,Em,C,D,G,G,D/F#,Em,C,D,G,Em,D,G,C,Em,...
# 677   A     0                             A,E,Dsus2,A,A7,D,A,E,A
# 222         0  C,G,F,C,G,F,C,G,F,G,C,G,F,G,C,G,F,G,C,G,F,G,C,...
# 261   A     0  A,A,D,A,A,D,A,A,E,A,D,A,E,D,A,A,D,A,A,D,A,A,E,...
# 20    A     0  A,D,D,A,E,A,A,D,D,A,E,A,D,D,A,E,A,D,D,A,E,A,D,...
# 156   D     0  D,G,D,A7,D,G,D,A7,D,D,G,D,A7,D,G,D,A7,D,D,G,D,...
# 712         0  A,A,G,G,Bm,Bm,D,A,D,D,A,D,D,A,G,G,A,Bm,Bm,A,D,...
# 277  Am     0  Am,C,F,G,Am,C,F,C,G,C,Am,G,C,Am,C,F,C,G,C,F,Am...
# 536   A     0  E,E7,A,E,B7,E,E,E7,A,E,B7,E,E,E7,A,E,B7,E,E,E7...
# 51          0  A,E7,A,A,E7,A,A,D,A,A,E7,A,A,E7,A,A,E7,A,A,D,A...
# 344   A     0  A,D,A,D,A,E,A,A,D,A,D,A,E,A,A,D,A,D,A,E,A,A,D,...
# 59    G     0  G,G,Dsus4,Fadd9,G,C,Fadd9,C,G,Dsus4,Fadd9,G,C,...
# 893         0  A,A,A/G#,D,A,E,A,A/G#,D,A,E,D,F#m,E,A,F#m,D,A,...
# 632         2  Dsus2,D,A,Bm,Dsus2,G,A,Bm,Dsus2,G,D,A,G,D,A,G,...
# 692   F     3  D,D,Dsus2,Dsus2,D,G,A,D,G,D,G,A,G,A,D,G,D,G,A,...
# 42          2  D,G,D,G,D,G,A7,A7,D,G,D,G,D,G,A7,A7,G,G,D,D,G,...
# 139         1  C,Fsus2,C,C,Fsus2,C,G,Fsus2,C,G,Fsus2,C,C,Fsus...
# ..   ..   ...                                                ...
# 328         0  Am,G,Dm,Am,Am,G,Dm,Am,Am,G,Dm,Am,Am,G,Dm,Am,Am...
# 406   G     0  G,D/F#,Em,D,C,G,D/F#,Em,D,C,G,D/F#,Em,D,C,G,D/...
# 252         1  Em,C,Dsus,D,Em,C,D5,Dadd4,G5,Bm,Em,D,G5,Bm,Em,...
# 442         0  A,E/G#,F#m,D,E7sus4,E7,A,A,E,F#m,D,A,E,A,E,F#m...
# 433         2  D,D/F#,F#m,C#m7,E7,E/G#,A,E,F#m,C#m7,D,E,A,E,F...
# 664         1  G#madd6,G#m,G#m7,E,A,B,F#m,G#m,D4,D,D,G,Bm,D,G...
# 181   B     0  A,C#m,B,D#m,G#m,B,A,C#m,G#m,A,C#m,B,D#m,G#m,B,...
# 918   C     4  C,F,Dm7,Am,G,Fm,Cmaj7,C,F,C,Dm7,Am,F,C,Dm7,Am,...
# 221         0  B7,Em7,G,F#m,B7,Em7,Dm7,G7,Bm,Em7,Am7,D7sus,G,...
# 62   Am     0  Am,G,A,D,C#m,F#m7b5,E,F#m,Fmaj7,C,Bm,Am,F#m7b5...
# 166         0  Em,G,Em,G,Em,G,Em,G,Em,G,Em,G,Em,G,Em,G,Em,G,E...
# 146   F     0  F,Am,Bb,Am,Gm7,F,A7,Dm,C#,Gm7,C,C7,F,Bbmaj7,C7...
# 482         0  B,C#m,G#m,A,Emaj7,F#m,B,Am,G,F,C,B,C#m,G#m,A,B...
# 267         0  D,D,D,D,D,D,D,Bm,A/C#,Em,F#7,Bm,G,D,D,D,D,Bm,A...
# 245  Gm     0  Fmaj7,Fmaj7,Gm,F,C,C7,F,Ab,Bb,Gm,F,C,C7,A,G,F,...
# 855         0  F,Am,Dm,Bb,F,Gm,Am,Bb,F,Gm,Am,Bb,F,Am,Dm,Bb,F,...
# 489  Am     0  C#,F#,B,E,G#,C#,Am,Em,F,Am,Em,F,Am,Em,F,Am,Em,...
# 314  Eb     1  F,Bb,Gm,C,F,Bb,Gm,C,A,D,G,A,F#m,Bm,G,C,A,D,G,A...
# 133         0  Cm,Cm,Cm,Cm,Eb,Ab/Eb,Eb,Ab/Eb,Eb,Cm,F7,Bb,Ab/B...
# 897   E     0  E,G#m,A,B,E,G#m,A,B,E,G#m,A,B,G#,C#m,F#m,E,C#7...
# 161         0  A,Bm7,C#m,Bm7,A,Bm7,C#m,Bm7,A,Bm7,C#m,Bm7,A,Bm...
# 537         0  A7,D,Bm,Em7,A9,Em7,D,Bm7,Em7,A7,D,Bm7,Em7,Gdim...
# 102  Bb     0  Gm7,C7,Gm7,C7,Gm7,C7,F7,Cm7,F7,Bb,Cm7,Bb,F7,Bb...
# 657         0  C,D7,F,C,C,D7,F,C,C,D7,F,C,C,D7,F,C,D7,F,C,C,D...
# 172         0  F,Am7,Dm7,Gm7,C7,F,F7,Bb,Gm7,D7,Gm,Dm,Gm,Gm7,G...
# 6           0                                        F,G,G#,A,A#
# 917   D     0  D,F#m7,Gmaj7,A6,D,F#m7,Gmaj7,Bm7,A,Am7,B,Gmaj7...
# 64          0  E,A,C#m,B,A,C#m,B,A,C#m,B,C#m,B,A,B,A,B,C#m,C#...
# 120  Em     0  Em,Am7,C,Am7,Em,D,C,G,D,C,G,D,C,G,D,C,G,D,C,Em...
# 666   C     0  C,G,F,C,F,C,D7,G,C,G,F,C,F,G,C,G,C,G,F,C,F,C,D...
#
# [733 rows x 6 columns]
