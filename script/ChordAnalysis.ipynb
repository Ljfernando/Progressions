# %%
import pymysql.cursors
import pandas as pd
import numpy as np
import re
import math

# %%
def connect_to_database(db="UltimateGuitarTabs"):
    """
    Connects to MySQL database and 
    returns the connection"""
    db = pymysql.connect(host="localhost",  # your host 
                         user="root",       # username
                         passwd="",     # password
                         db=db)   # name of the database
    return db

def print_table(tableName):
    """
    Prints database table
    """
    db = connect_to_database()
    cur = db.cursor()

    # Select data from table using SQL query.
    cur.execute("SELECT * FROM "+tableName)
    # print the first and second columns      
    for row in cur.fetchall() :
        print(row)
        
def get_table(tableName):
    db = connect_to_database()
    cur = db.cursor()

    # Select data from table using SQL query.
    cur.execute("SELECT * FROM "+tableName)
    
    return(cur.fetchall())

# %%
Chords = pd.DataFrame(list(get_table('Chords')), columns=['Song', 'Artist', 'Key', 'Capo', 'Chords'])
Chords
# Out:
#                                   Song                 Artist  Key  Capo  \
# 0                           Hallelujah           Jeff Buckley   Db     1
# 1                             Im Yours             Jason Mraz    G     4
# 2                           Wonderwall                  Oasis  F#m     2
# 3                   Wish You Were Here             Pink Floyd   Em     0
# 4                      Hey Soul Sister                  Train    C     4
# 5                           Wonderwall                  Oasis    D     0
# 6                   The Only Exception               Paramore    B     4
# 7                           Love Story           Taylor Swift    C     2
# 8                                Creep              Radiohead    G     0
# 9                                 Iris          Goo Goo Dolls   Bm     0
# 10                           Let It Be            The Beatles    C     0
# 11           Cant Help Falling In Love          Elvis Presley    C     2
# 12                        Viva La Vida               Coldplay    D     1
# 13             Dont Look Back In Anger                  Oasis    C     0
# 14                            Im Yours             Jason Mraz    C     0
# 15                         Radioactive        Imagine Dragons   Am     2
# 16                            Hey Jude            The Beatles    F     0
# 17                      Counting Stars            OneRepublic   Am     4
# 18                  You Belong With Me           Taylor Swift    D     4
# 19                           Breakeven             The Script   Em     3
# 20     Good Riddance Time Of Your Life              Green Day    G     0
# 21          Boulevard Of Broken Dreams              Green Day   Em     1
# 22                       Say Something      A Great Big World   Bm     0
# 23                     Pumped Up Kicks      Foster the People   Fm     0
# 24                     Youre Beautiful            James Blunt    G     8
# 25                        Chasing Cars            Snow Patrol    A     0
# 26                             Imagine            John Lennon    C     0
# 27                        Use Somebody          Kings of Leon          0
# 28           The Man Who Cant Be Moved             The Script    G     3
# 29     I Will Follow You Into The Dark    Death Cab for Cutie   Am     5
# ..                                 ...                    ...  ...   ...
# 955                   Times Like These           Foo Fighters          0
# 956                       Tainted Love              Soft Cell          3
# 957                    I Am The Walrus            The Beatles          0
# 958                Time Is Running Out                   Muse          0
# 959              I Want You To Want Me            Cheap Trick          0
# 960                          Ignorance               Paramore          0
# 961        I Dont Want To Miss A Thing              Aerosmith          0
# 962                      Im A Believer            The Monkees          0
# 963                          Hey Julie     Fountains of Wayne          0
# 964  I Could Sing Of Your Love Forever             Sonicflood          0
# 965                     Jack And Diane        John Mellencamp          0
# 966                        Snow Hey Oh  Red Hot Chili Peppers  Ebm     0
# 967                The Drugs Dont Work              The Verve          0
# 968                       Heaven Knows             Rick Price          0
# 969               Us Against The World               Coldplay          3
# 970                               Beth                   KISS          0
# 971                     Head Over Feet      Alanis Morissette          0
# 972       While My Guitar Gently Weeps            The Beatles          0
# 973                     Safe And Sound         Capital Cities          0
# 974                   Ill Stand By You         The Pretenders          0
# 975                        Radioactive        Imagine Dragons          2
# 976                  Please Forgive Me            Bryan Adams          0
# 977                             Dreams          Fleetwood Mac          0
# 978                              Lucky              Radiohead          0
# 979                  Love Interruption             Jack White          0
# 980                   Always Somewhere              Scorpions          0
# 981                         In My Life            The Beatles          2
# 982                              Angel        Sarah McLachlan          1
# 983                    Come As You Are                Nirvana          0
# 984        I Want To Know What Love Is              Foreigner          0
#
#                                                 Chords
# 0    C,Am,C,Am,C,Am,C,Am,F,G,C,G,C,F,G,Am,F,G,E7,Am...
# 1    G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G,D,Em,C,G...
# 2    Em7,G,Dsus4,A7sus4,Em7,G,Dsus4,A7sus4,Em7,G,Ds...
# 3    Em7,G,Em7,G,Em7,A7sus4,Em7,A7sus4,G,C,D/F#,G,D...
# 4    C,G,Am,F,C,G,Am,F,C,G,Am,F,G,C,G,Am,F,C,G,Am,F...
# 5    F#m,A,Esus4,B,F#m,A,Esus4,B,F#m,A,Esus4,B,F#m,...
# 6    G,Dm,Cmaj7,G,Dm,Cmaj7,G,Dm,Cmaj7,G,Dm,Cmaj7,G,...
# 7    C,G,Am,F,C,F,Am,F,C,F,Am,G,F,G,Am,C,F,G,Am,F,G...
# 8    G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G...
# 9    Bm,Bsus2,G,D,Em,G,Bm,A,G,D,Em,G,Bm,A,G,D,Em,G,...
# 10   C,G,Am,Fmaj7,F6,C,G,F,Dm,C,C,G,Am,Fmaj7,F6,C,G...
# 11   C,G,Am,C,G,C,Em,Am,F,C,G,F,G,Am,F,C,G,C,C,Em,A...
# 12   C,D,G,Em,Em,C,D,G,Em,C,D,G,Em,C,D,G,Em,Em,C,D,...
# 13   C,F,C,F,C,G,Am,E,F,G,C,Am,G,C,G,Am,E,F,G,C,Am,...
# 14   C,G,Am,F,C,G,Am,F,C,G,Am,F,D7/F#,C,G,Am,F,C,G,...
# 15   Am,C,G6,Am,Am,C,G,D,Am,C,G,D,Am,C,G,D,Am,C,G,D...
# 16   F,C,C,C6,C7,C7sus4,C7,F,Bb,F,C,F,F,C,C,C6,C7,C...
# 17   Am,C,G,F,Am,C,G,F,Am,C,G,F,Am,C,G,F,F,Am,C,G,F...
# 18   D,D,D,A,Em,G,D,A,Em,G,Em,G,D,A,Em,G,A,D,A,Em,G...
# 19   C,G,D,Em,Em,D,G,Am7,Em,D,G,Am7,Em,D,G,Am7,Em,D...
# 20   G,G,Cadd9,D,G,G,Cadd9,D,G,C,D,G,C,D,Em,D,C,G,E...
# 21   Em,G,D,A,Em,G,D,A,Em,Em,G,D,A,Em,G,D,A,Em,G,D,...
# 22   Bm,G,D,Asus4,Bm,G,D,Asus4,Bm,G,D,Asus4,Bm,G,D,...
# 23   Fm,Ab,Eb,Bb,Fm,Ab,Eb,Bb,Fm,Ab,Eb,Bb,Fm,Ab,Eb,B...
# 24   G,G/F#,Em7,Cadd9,G,G/F#,Em7,Cadd9,G,G/F#,Em7,C...
# 25   A,A,E/G#,D,A,A,E/G#,D,A,A,E/G#,Dmaj7,A,A,E/G#,...
# 26   C,Cmaj7,F,Cadd9,Cadd9,Cmaj7,F,Cadd9,C,Cmaj7,F,...
# 27   C,F,F,C,F,F,Am,F,F,Am,F,F,C,F,C,F,Am,C,F,Am,C,...
# 28   G,D/F#,C,G,D/F#,Am,C,G,D/F#,Am,C,G,D/F#,Am,C,G...
# 29   Am,C,F,C,Am,C,G,Am,C,E,Am,F,Fm,F,C,G,F,C,G,Am,...
# ..                                                 ...
# 955  D,C,Dsus2,D,C,D,D,C,D,C,D,C,D,C,D,C,D,D,D,D,D,...
# 956  Em,G,C,G,Em,G,C,G,Em,G,C,G,Em,G,C,G,Em,G,C,G,E...
# 957  B,B,A,A6,G,F,F6,E,E7,D,D7,A,C,D,A,C,D,A,A,Dadd...
# 958  Am,B,E,F,G,Am,B,E,F,G,Am,B,A,E,F,G,Am,B,E,F,G,...
# 959  A,G,D,A,A,A/G#,F#m,D,D/C#,A,A/G#,F#m,D,D/C#,A,...
# 960  D,Bm,D,G,A,Em,Bm,D,Bm,D,G,D,G,D,Bm,D,Bm,D,G,D,...
# 961  E,C#m,E,Bm,A,D,A/C#,Bm,G,F#m,Em,A,D,A/C#,Bm,G,...
# 962  G,D,F,G,D,F,G,C,G,C,G,C,G,D,G,C,G,C,G,C,G,C,G,...
# 963  G,C,G,D,G,C,G,D,G,C,G,D,G,C,G,D,Em,C,D,G,Em,C,...
# 964  G,Em,C,D,G,Em,C,D,G,D,Em,C,G,D,Em,C,Am,G,Am,G,...
# 965  G,D,G,D,C,G,D,C,D,G,D,C,D,G,G,D,C,D,G,D,C,D,G,...
# 966  G#m,E,B,F#,G#m,E,B,F#,G#m,E,B,F#,G#m,E,B,F#,G#...
# 967  C,C2,Am,Am7,Em,F,G,C,C2,C,C,C2,Am,Am7,Em,F,G,C...
# 968  C,F,C,F,C,F,G,Em,Am,Am7,F,G,C,F,G,Em,Am,F,Am,F...
# 969  E,A,D,F#,B,E,A,Asus4,E,Esus4,D,D/C#,A,Asus4,A,...
# 970  C,Dm,G,C,Dm,G,C,Dm,Em,Am,G,F,G,C,Esus4,E,Am,G,...
# 971  C,G,Am,F,C,G,Am,F,C,G,Am,F,C,G,Am,F,C,G,Am,F,C...
# 972  Am,D/F#,F,Am,G,D,E,Am,D/F#,F,C,G,C,E,A,C#m,F#m...
# 973  F,C,Am,G,F,C,Am,G,F,C,Am,G,F,C,Am,G,F,C,Am,G,F...
# 974  D,Bm,A,G,D,F#m,G,D/F#,A,D,F#m,G,Bm,A,F#m,Bm,F#...
# 975  Am,C,G,D,Am,C,G,D,Am,C,G,Am,C,G,D,Am,C,G,D,Am,...
# 976  A,E,F#m,E,D,E,A,A5,A,E,F#m,C#m,D,A,E,A,C#,F#m,...
# 977  Am,G,F,Am,G,F,Am,G,F,G,Am,G,F,G,F,G,F,G,F,G,F,...
# 978  Em,Am,G,Bm,Em,C,G,Bm,Em,Em,Am,G,Bm,Em,C,G,Bm,E...
# 979  E,E,G,A,E,E,G,A,E,E,G,A,E,E,G,A,E,E,G,D,A,E,G,...
# 980  C,G,F,E,Am,C,G,F,E,Am,C,G,F,E,Am,C,G,F,E,Am,C,...
# 981  G,D,G,D,G,D,Em,G7,C,Cm,G,G,D,Em,G7,C,Cm,G,Em,C...
# 982  C,Dm7,F,C,F,G,Dm7,F,C,F,G,Dm7,F,C,F,G,Dm7,F,C,...
# 983  F#m,E,F#m,E,F#m,E,F#m,E,F#m,E,F#m,E,F#m,E,F#m,...
# 984  Em,D,G,C,Em,Em,D,G,C,Em,Em,D,G,C,Em,Em,D,G,C,E...
#
# [985 rows x 5 columns]

# %%
def fix_accidental(note, accidental):
    notes = np.asarray(['A', 'B', 'C', 'D', 'E', 'F', 'G'])

    note_idx = int(np.where(notes == note)[0])
    if accidental == '#':
        # Account for B# or E#
        if note == 'B':
            return('C', '')
        elif note == 'E':
            return('F', '')
        return(note,accidental)
    elif accidental == 'b':
        # Account for Cb or Fb
        if note == 'C':
            return('B', '')
        elif note == 'F':
            return('E', '')
        return(notes[note_idx - 1],'#')
    else:
        return(note, accidental)
            
        
def clean_chords(chords):
    """
    This function takes in a comma-separated string of 
    chords and cleans it by removing any base note variations, or
    other chord embelishments.  Diminished labels are kept as these
    are used in the chord progression table. The purpose of this
    is to clean the chords to match the labels within the chord
    progression table.
    
    returns:
        new_chords - array of newly cleaned chords to be tabulated
                        by the chord progression table
    """
    
    # Pattern grouping: 1=(chord pitch) 2=(base note) 3=(chord type) 4=(base note)
    pattern = "^([A-G]+)(\/[A-G]*[b#])*([(?m)|(?m\d)|(?b\d)|(?#\d)|(?maj\d)|\
    (?add\d)|(?sus\d)|(?aug)|(?aug\d)|(?dim)|(?dim\d)]*)(\/[A-G]*[b#])*"        
    prog = re.compile(pattern)

    pattern2 = "^([A-G])([b#])?(m$|m\d$)?(dim$|dim\d$)?"
    prog2 = re.compile(pattern2)

    chords = chords.split(',')
    new_chords = [""]*len(chords)
    for i in range(len(chords)):
        curr_chord = chords[i]
        groups = prog.findall(curr_chord)[0] 
        no_base = groups[0] + groups[2]
        no_num = re.sub(pattern="\d", repl="", string=no_base)

        groups = prog2.findall(no_num)[0]
        note,accidental = fix_accidental(groups[0], groups[1])
        new_chords[i] = note + accidental + groups[2] + groups[3]
        
    return(new_chords)


def get_key_tbls():
    """
    Helper function that reads in a chord progression table
    and creates a dictionary that maps chord names to their
    indices on the chord progression table. This dictionary
    will be used to tabulate a 'key table' to determine the
    key of a song.
    
    returns:
        Key_dict - Dictionary mapping chord names to indices
        Keys - array of keys that correspond to the order
                of the progression table
    """
    Key_tbl = pd.read_csv('../data/key_table.csv')
    Keys = list(Key_tbl.key)
    Tbl = np.asmatrix(Key_tbl.iloc[:,1:8])

    # Storing all possible chords 
    all_chords = []
    for i in range(Tbl.shape[0]):
        for j in np.asarray(Tbl[i])[0]:
            all_chords.append(j)
    all_chords = np.unique(all_chords)
    
    # Creating dict(key='chord', val='indices in progression tbl')
    Key_dict = {}
    for chord in all_chords:
        Key_dict[chord] = np.where(Tbl == chord)

    return(Key_dict, Keys)

def is_rel_min(comp_key, act_key):
    """
    Determines if the actual key marked indicated
    UltimateGuitarTabs.com is the relative minor
    of the actual key (i.e., Am(rel. minor) and C(actual))
    
    args:
        comp_key - Computed key
        act_key - UltimateGuitarTabs.com key
    returns:
        - True if it's relative minor, False otherwise
    """
    notes = ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']
    if str(act_key[-1]) != 'm': #If not minor, return 
        return(False)
    if len(comp_key) == 2:
        note, accidental = fix_accidental(comp_key[0],comp_key[1])
        comp_key = note + accidental
    comp_idx = np.where(np.asarray(notes) == comp_key)[0][0]
    rel_min_idx = comp_idx - 3
    if notes[rel_min_idx] + 'm' == act_key:
        return(True)

def compute_key(Key_dict, Keys, chords):
    """
    Computes the key of a song by analyzing
    the chords used within the song. A theoretical
    key matrix where each row specifies the types of chords
    that coincide with a key is used to tabulate
    the existing chords. The largest row sum is the
    computed key of the song. 
    
    args:
        Key_dict - Python dictionary containing all possible
                   chords and their indexes in the theoretical key matrix.
                   This is used to tabulate a matrix of zeros.
        Keys - List of possible keys corresponding to theoretical key matrix
        chords - String of chords separated by commas
                   
    returns:
        - The computed key
        - List of cleaned chords, only major or minor
    """
    chords = clean_chords(chords)
    count_mat = np.zeros((12,7)) # Matrix of zeros to tabulate chord occurences
    start_chord = chords[0]
    # Tabulating chords
    for chord in chords:
        count_mat[Key_dict[chord]] += 1
        
    computed_key = Keys[np.argmax(np.sum(count_mat, axis = 1))]
    return(computed_key, chords)
    
def transpose_C(Key_dict, Keys, chords, states):
    notes = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    comp_key, chords = compute_key(Key_dict, Keys, chords)
    
    new_chords = [""]*len(chords) # Empty list for new chords
    if comp_key == 'C':
        for chord in chords:
            states.add(chord)
        return(states, \
               {'orig_key': comp_key, \
                'trans_chords': chords})
    else:
        steps = np.where(np.asarray(notes) == comp_key)[0][0]
        for i in range(len(chords)):
            is_min = False
            curr_chord = chords[i]
            if curr_chord[-1] == 'm':
                is_min = True
                curr_chord = curr_chord[0:-1]
            chord_idx = np.where(np.asarray(notes) == curr_chord)[0][0]
            new_chord_idx = chord_idx - steps
            new_chords[i] = notes[new_chord_idx] + 'm' if is_min else notes[new_chord_idx]
            states.add(new_chords[i])
        return(states, \
               {'orig_key': comp_key, \
                'trans_chords': new_chords})
def get_songs():
    Key_dict, Keys = get_key_tbls()

    songs = [""]*Chords.shape[0]
    states = set()
    for i in range(Chords.shape[0]):
        states, songs[i] = transpose_C(Key_dict, Keys, Chords['Chords'][i], states)
    states = sorted(list(states))
    return(states, songs)

def create_transition_mat(states, chords):
    num_states = len(states)
    trans_mat = np.zeros((num_states, num_states))
    for i in range(1, len(chords)):
        curr_chord = chords[i - 1]
        curr_chord_idx = np.where(np.asarray(states) == curr_chord)[0][0]
        
        next_chord = chords[i]
        next_chord_idx = np.where(np.asarray(states) == next_chord)[0][0]
        trans_mat[curr_chord_idx, next_chord_idx] += 1

    row_sums = np.sum(trans_mat, axis = 1)
    trans_mat = trans_mat/row_sums
    return(np.nan_to_num(trans_mat))

def compute_euclidean(mat1, mat2):
    # Computes euclidean distance between two
    # transition matrices
    # NOTE: Will produce runtime warning with division by zero
    mat_dif = mat1 - mat2
    return(math.sqrt(np.sum(np.multiply(mat_dif, mat_dif)))/mat1.shape[0])

def get_similar_songs(states, chords, all_songs):
    tm = create_transition_mat(states,chords)
    dist = [0]*len(all_songs)
    for i in range(len(all_songs)):
        curr_tm = create_transition_mat(states,all_songs[i]['trans_chords'])
        dist[i] = compute_euclidean(tm, curr_tm)
        
    dist_ord = np.argsort(dist) # Sorting by distance ascending
    
    idxs = np.unique(list(Chords['Song'][dist_ord]), return_index=True)[1] # Indexes of unique entries
    # np.unique() automatically sorts, so we must resort by distance
    sim_songs = list(Chords['Song'][dist_ord[sorted(idxs)]])
    return(sim_songs)

# %%
states, songs = get_songs()
test_chords = songs[4]['trans_chords']
print(Chords[4:5])
# Out:
#               Song Artist Key  Capo  \
# 4  Hey Soul Sister  Train   C     4
#
#                                               Chords
# 4  C,G,Am,F,C,G,Am,F,C,G,Am,F,G,C,G,Am,F,C,G,Am,F...

# %%
sim = get_similar_songs(states, test_chords, songs)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:188: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:188: RuntimeWarning: divide by zero encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:196: RuntimeWarning: overflow encountered in multiply

# %%
sim
# Out:
# ['Hey Soul Sister',
#  'Here Without You',
#  'Open The Eyes Of My Heart',
#  'Wonderful Tonight',
#  'Sex',
#  'Push',
#  'Go Your Own Way',
#  'Your Call',
#  'Youre Beautiful',
#  'The Funeral',
#  'Down Under',
#  'Run',
#  'White Horse',
#  'Fall For You',
#  'Many Of Horror',
#  'She Will Be Loved',
#  'You Found Me',
#  'Almost Lover',
#  'Naive',
#  'Touch The Sky',
#  'Who Am I',
#  'The Best Day',
#  'Breathe',
#  'Your Guardian Angel',
#  'Please Please Please Let Me Get What I Want',
#  'Right Here Waiting',
#  'Numb',
#  'Flaws',
#  'Forever And Always',
#  'Two Is Better Than One',
#  'If I Ever Leave This World Alive',
#  'Dont Think Twice Its All Right',
#  'Somewhere Only We Know',
#  'One Of Us',
#  'I Want To Break Free',
#  'At The Bottom Of Everything',
#  'Torn',
#  'There Is A Light That Never Goes Out',
#  'For The First Time',
#  'Can You Feel The Love Tonight',
#  'Dreams',
#  'King And Lionheart',
#  'All I Want',
#  'Im Yours',
#  'Thats What You Get',
#  'Glycerine',
#  'Let It Be',
#  'Over You',
#  'Girls Just Want To Have Fun',
#  'Here I Go Again',
#  'As Long As You Love Me',
#  'Beast Of Burden',
#  'All Along The Watchtower',
#  'Life After You',
#  'Amnesia',
#  'All The Small Things',
#  'Yellow',
#  'Disarm',
#  'Unsteady',
#  'Chicken Fried',
#  'Just Breathe',
#  'Misery Business',
#  'Halaga',
#  'Kryptonite',
#  'Dont Go Away',
#  'Thinking Of You',
#  'Kiss',
#  'With Or Without You',
#  'In The Air Tonight',
#  'After The Gold Rush',
#  'Zombie',
#  'Stop And Stare',
#  'Pare Ko',
#  'I Could Sing Of Your Love Forever',
#  'Through Glass',
#  'Ironic',
#  'Castle Of Glass',
#  'In The Aeroplane Over The Sea',
#  'Give Me One Reason',
#  'Wish You Were Here',
#  'You Dont Know',
#  'Bleeding Out',
#  'Hollywood Hills',
#  'Friday Im In Love',
#  'Apologize',
#  'Marry Me',
#  'Suspicious Minds',
#  'Margaritaville',
#  '21 Guns',
#  'Hymn For The Weekend',
#  '74-75',
#  'Breakfast At Tiffanys',
#  'Breakaway',
#  'Face Down',
#  'Remembering Sunday',
#  'Young Volcanoes',
#  'Mr Jones',
#  'Anyone Else But You',
#  'Welcome To My Life',
#  'Heartbreak Girl',
#  'Someday',
#  'Cool Kids',
#  'Home',
#  'Free Bird',
#  'Fifteen',
#  'Id Rather Go Blind',
#  'Talk Tonight',
#  'Beat It',
#  'Now And Forever',
#  'If It Means A Lot To You',
#  'Little Talks',
#  'In The End',
#  'Teenagers',
#  'Teenage Dirtbag',
#  'Fairytale Of New York',
#  'Tadhana',
#  'The River',
#  'Breakeven',
#  'Time After Time',
#  'Have You Ever Seen The Rain',
#  'Be Alright',
#  'Hide And Seek',
#  'Hey Julie',
#  'Say Something',
#  'Dead Flowers',
#  '100 Years',
#  'Hero Of War',
#  'Hallelujah',
#  'Waiting On The World To Change',
#  'Its My Life',
#  'You Shook Me All Night Long',
#  'Hosanna',
#  'Jumper',
#  'Dont Stop Believin',
#  'Toes',
#  'All Out Of Love',
#  'Million Reasons',
#  'The Messenger',
#  'Its Time',
#  'God Of Wonders',
#  'Shake It Out',
#  'Basket Case',
#  'Snow Hey Oh',
#  'Something I Need',
#  'Tuesdays Gone',
#  'Lips Of An Angel',
#  'Happy Ending',
#  'Whats Up',
#  'Free Fallin',
#  'Lost',
#  'Bad Moon Rising',
#  'New Slang',
#  'Drive By',
#  'Your Body Is A Wonderland',
#  'Good Riddance Time Of Your Life',
#  'Fields Of Gold',
#  'Jack And Diane',
#  'Wherever You Will Go',
#  'Fake Plastic Trees',
#  'Leave Out All The Rest',
#  'Beauty And A Beat',
#  'Under Pressure',
#  'Iridescent',
#  'Pieces',
#  'Love Story',
#  'How You Remind Me',
#  'I Still Havent Found What Im Looking For',
#  'Fix You',
#  'Chasing Cars',
#  'Your Love Never Fails',
#  'Turn The Page',
#  'Black Or White',
#  'Iris',
#  'Youth',
#  'Johnny B Goode',
#  'Dare You To Move',
#  'She Moves In Her Own Way',
#  'Dear Maria Count Me In',
#  'The Joker',
#  'With Me',
#  'Still Into You',
#  'Runaway',
#  'Colder Weather',
#  'Big Yellow Taxi',
#  'Mr Tambourine Man',
#  'Youre Gonna Go Far Kid',
#  'Stairway To Heaven',
#  'Breathe 2 Am',
#  'Welcome To The Black Parade',
#  'Dream Catch Me',
#  'Heartache',
#  'Every Rose Has Its Thorn',
#  'Everglow',
#  'Piano Man',
#  'Take On Me',
#  'Human',
#  'Simple Man',
#  'Jealous Guy',
#  'Landslide',
#  'Burning Love',
#  'Stay The Night',
#  'Nobodys Home',
#  'Save Tonight',
#  'All Summer Long',
#  'I Wont Back Down',
#  'Dont Look Back In Anger',
#  'Down On The Corner',
#  'Who Says',
#  'Viva La Vida',
#  'We Are The People',
#  'Goodbye My Lover',
#  'Wake Me Up When September Ends',
#  'Peaceful Easy Feeling',
#  'Atlantic City',
#  'Lady In Black',
#  'Love You Till The End',
#  'Picture',
#  'Always Somewhere',
#  'Who Knew',
#  'If You Could Only See',
#  'Im A Believer',
#  'Hows It Going To Be',
#  'Miserable At Best',
#  'All I Want Is You',
#  'Dog Days Are Over',
#  'Bring Me To Life',
#  'Drag Me Down',
#  'Blowin In The Wind',
#  'Use Somebody',
#  'Dear Mr President',
#  'I Will Follow You Into The Dark',
#  'Losing My Religion',
#  'American Idiot',
#  'Slow Dancing In A Burning Room',
#  'Holiday',
#  'My Happy Ending',
#  'Rockstar',
#  'I Want To Hold Your Hand',
#  'Second Chance',
#  'Another Brick In The Wall Part 2',
#  'Wonderwall',
#  'High Hopes',
#  'Harvest Moon',
#  'Better Man',
#  'Sex On Fire',
#  'Last Kiss',
#  'I Walk The Line',
#  'One',
#  'Aint No Rest For The Wicked',
#  'Santeria',
#  'The Rose',
#  'Folsom Prison Blues',
#  'Proud Mary',
#  'We Are Going To Be Friends',
#  'Im On Fire',
#  'I Saw Her Standing There',
#  'Like A Rolling Stone',
#  'Yellow Submarine',
#  'Stand By Me',
#  'Ooh La',
#  'Plush',
#  'The Scientist',
#  'Oh Darling',
#  'Let Her Cry',
#  'I Dont Love You',
#  'Somebody Else',
#  'A Thousand Miles',
#  'Heart Of Gold',
#  'The Drugs Dont Work',
#  'Ticket To Ride',
#  'The Passenger',
#  'Little By Little',
#  'Times Like These',
#  'Photograph',
#  'Thunder',
#  'Fat Bottomed Girls',
#  'Watch Over You',
#  'Heaven',
#  'Look What Youve Done',
#  'Sultans Of Swing',
#  'Mother',
#  'Never Too Late',
#  'Everybody Talks',
#  'Kids',
#  'Ill Be',
#  'Walk',
#  'Everywhere',
#  'Hurricane',
#  'Sing',
#  'Misguided Ghosts',
#  'Come Together',
#  'Thank You For Loving Me',
#  'Cant Help Falling In Love',
#  'Sway',
#  'Everlong',
#  'High And Dry',
#  'Heaven Knows',
#  'Bed Of Roses',
#  'Come Home',
#  'You And I Both',
#  'Someone New',
#  'Lucky',
#  'Knockin On Heavens Door',
#  'Angels',
#  'Heroes',
#  'Ang Huling El Bimbo',
#  'I Want You To Want Me',
#  'My Heart',
#  'Your Song',
#  'The Reason',
#  'Far Away',
#  'Dont Dream Its Over',
#  'The Boxer',
#  'Slide',
#  'A Sky Full Of Stars',
#  'Perfect',
#  'Starlight',
#  'Annies Song',
#  'Secrets',
#  'Shadow Of The Day',
#  'Blister In The Sun',
#  'Bonfire Heart',
#  'Sweet Home Alabama',
#  'Sister Golden Hair',
#  'Maggie May',
#  'We Will Rock You',
#  'The Times They Are A-Changin',
#  'Oh Comely',
#  'Angie',
#  'Best Of You',
#  'Ignorance',
#  'We Are Young',
#  'It Aint Me Babe',
#  'Feeling Good',
#  'Chocolate',
#  'You Belong With Me',
#  'Seaside',
#  'Paradise',
#  'Comfortably Numb',
#  'Working Class Hero',
#  'No Rain',
#  'Alone',
#  'Eleanor Rigby',
#  'Two Princes',
#  'Take It Easy',
#  'All Apologies',
#  'Yesterday',
#  'My Life Would Suck Without You',
#  'Honky Tonk Women',
#  'Crushcrushcrush',
#  'Northern Downpour',
#  'Into The Mystic',
#  'Outside',
#  'Some Nights',
#  'The Man Who Sold The World',
#  'Green Eyes',
#  'Still Loving You',
#  'Broken',
#  'What I Got',
#  'Bright',
#  'California',
#  'Love Will Keep Us Alive',
#  'Another Day In Paradise',
#  'Its All Over Now Baby Blue',
#  'Time',
#  'Stuck In The Middle With You',
#  'If Today Was Your Last Day',
#  'You Wont Relent',
#  'The Man Who Cant Be Moved',
#  'Behind Blue Eyes',
#  'It Ends Tonight',
#  'Sunday Morning',
#  'Enter Sandman',
#  'Two-Headed Boy',
#  'When You Were Young',
#  'Jailhouse Rock',
#  'Brothers In Arms',
#  'Half Of My Heart',
#  'Hey You',
#  'Cigarette Daydreams',
#  'A Horse With No Name',
#  'Aint It Fun',
#  'Wont Go Home Without You',
#  'Polly',
#  'Fast Car',
#  'How Deep Is Your Love',
#  'Dude I Totally Miss You',
#  'Hey Stephen',
#  'Adams Song',
#  'The Kill',
#  'Forever Young',
#  'Back In Black',
#  'Imagine',
#  'You Cant Always Get What You Want',
#  'Two Steps Behind',
#  'I Write Sins Not Tragedies',
#  'Fire And Rain',
#  'Champagne Supernova',
#  'Carry On',
#  'New Shoes',
#  'Piece Of My Heart',
#  'True Colors',
#  'Sex And Candy',
#  'To Love Somebody',
#  'Stop Crying Your Heart Out',
#  'I Dont Want To Talk About It',
#  'My Immortal',
#  'I Want To Know What Love Is',
#  'Renegades',
#  'Lovesong',
#  'Gone Gone Gone',
#  'Ayo Technology',
#  'Sugar Were Going Down',
#  'God Only Knows',
#  'Eye Of The Tiger',
#  'Highway To Hell',
#  'The Way I Am',
#  'Beth',
#  'Father And Son',
#  'Wind Of Change',
#  'Best Day Of My Life',
#  'Youve Got The Love',
#  'Norwegian Wood',
#  'Believer',
#  'Paint It Black',
#  'The Way I Loved You',
#  'Pompeii',
#  'Wicked Game',
#  'Come As You Are',
#  'Fearless',
#  'When I See You Smile',
#  'Fuck Her Gently',
#  'Wanted Dead Or Alive',
#  'Scar Tissue',
#  'Mardy Bum',
#  'Nutshell',
#  'Radioactive',
#  'Not Over You',
#  'Hey Jude',
#  'Scarborough Fair',
#  'Drive',
#  'I Dont Want To Miss A Thing',
#  'Brick By Boring Brick',
#  'You And Me',
#  'In My Life',
#  'Lonely Boy',
#  'I Am The Highway',
#  'Cant Buy Me Love',
#  'Hear You Me',
#  'Rocket Man',
#  'I Follow Rivers',
#  'Boulevard Of Broken Dreams',
#  'Hero',
#  'Carolina In My Mind',
#  'Please Forgive Me',
#  'Sunny Afternoon',
#  'Dancing In The Dark',
#  'Mr Brightside',
#  'The Difference',
#  'I And Love And You',
#  'Boys Dont Cry',
#  'Mad World',
#  'Beautiful Day',
#  'Drown',
#  'No Surprises',
#  'Another Love',
#  'Tage Wie Diese',
#  'How He Loves',
#  'American Girl',
#  'I Am The Walrus',
#  'Shut Up And Dance',
#  'Pumped Up Kicks',
#  'The One I Love',
#  'Los Angeles',
#  'Good Life',
#  'Breezeblocks',
#  'Summer Of 69',
#  'Decode',
#  '1973',
#  'She Looks So Perfect',
#  'This Is The Life',
#  'Mrs Robinson',
#  'I Cant Make You Love Me',
#  'Songbird',
#  'Little Wing',
#  'Float On',
#  'Every Breath You Take',
#  'Dust In The Wind',
#  'The Only Exception',
#  'Ball And Chain',
#  'Maybe Im Amazed',
#  'The Importance Of Being Idle',
#  'Beautiful',
#  'Work Song',
#  'Alive',
#  'Love Interruption',
#  'Love Will Tear Us Apart',
#  'Dreamer',
#  'Talkin Bout A Revolution',
#  'The Pretender',
#  'Me And Bobby Mcgee',
#  'Dancing In The Moonlight',
#  'Heart Shaped Box',
#  'Ligaya',
#  'Disenchanted',
#  'Counting Stars',
#  'Take Me To Church',
#  'I Started A Joke',
#  'Livin On A Prayer',
#  'Here Comes The Sun',
#  'Sign Of The Times',
#  'Roxanne',
#  'History',
#  'Safe And Sound',
#  'I Cant Get No Satisfaction',
#  'Where Did You Sleep Last Night',
#  'Angel',
#  'Are You Lonesome Tonight',
#  'Sympathy For The Devil',
#  'You And I',
#  'Help',
#  'With A Little Help From My Friends',
#  'Born To Be Wild',
#  'Drops Of Jupiter',
#  'I Wanna Be Yours',
#  'Exit Music For A Film',
#  'What Ive Done',
#  'Violet Hill',
#  'All My Loving',
#  'Amazed',
#  'Moondance',
#  'Ziggy Stardust',
#  'More Than A Feeling',
#  'Nothing Else Matters',
#  'Lay Lady Lay',
#  'By The Way',
#  'Boyfriend',
#  'Crazy Little Thing Called Love',
#  'Somebody To Love',
#  'All About You',
#  'The Final Countdown',
#  'Tears In Heaven',
#  'Black',
#  'Make It Mine',
#  'The Ballad Of Mona Lisa',
#  'This Love',
#  'I Miss You',
#  'Cancer',
#  'Beer Drinkers And Hell Raisers',
#  'All Star',
#  'Love Hurts',
#  'Fluorescent Adolescent',
#  'A Day In The Life',
#  'Little Black Submarines',
#  'Cant Stop',
#  'Us Against The World',
#  'Brain Damage',
#  'Old Man',
#  'Do I Wanna Know',
#  'Thriller',
#  'Everything I Do I Do It For You',
#  'Ill Stand By You',
#  'Sweet Caroline',
#  'The Night They Drove Old Dixie Down',
#  'Time Is Running Out',
#  'Bridge Over Troubled Water',
#  'Cornerstone',
#  'Sweater Weather',
#  'Closing Time',
#  'Love Of My Life',
#  'The Hungry Wolf',
#  'Death Of A Bachelor',
#  'Magasin',
#  'Billie Jean',
#  'Karma Police',
#  'Tainted Love',
#  'Just Like Heaven',
#  'Desecration Smile',
#  'Creep',
#  'Stacys Mom',
#  'The Weight',
#  'A Hard Days Night',
#  'Sunday Bloody Sunday',
#  'Exs And Ohs',
#  'Nights In White Satin',
#  'Half The World Away',
#  'Crazy',
#  'Take Me Out',
#  'Hey Joe',
#  'Unintended',
#  'Come On Eileen',
#  'Lola',
#  'To Be With You',
#  'Learn To Fly',
#  'Dirty Paws',
#  'Under The Bridge',
#  'Dreaming With A Broken Heart',
#  'Oh Pretty Woman',
#  'Love Me Tender',
#  'Across The Universe',
#  'Give Me Novacaine',
#  'Baby I Love Your Way',
#  'Last Request',
#  'Golden Slumbers',
#  'Smells Like Teen Spirit',
#  'Cant Stand It',
#  'Blackbird',
#  'Everybodys Changing',
#  'Tribute',
#  'Clocks',
#  'I Kissed A Girl',
#  'Breathe Me',
#  'Born To Run',
#  'Homeward Bound',
#  'Money For Nothing',
#  'Goodbye Yellow Brick Road',
#  'It Might Be You',
#  'Minsan',
#  'Listen To Your Heart',
#  'With A Smile',
#  'Rape Me',
#  'Total Eclipse Of The Heart',
#  'Melissa',
#  'Trouble',
#  'Space Oddity',
#  'I Will',
#  'We Can Work It Out',
#  'Ill Be There For You',
#  'Something',
#  'Sparks',
#  'Alapaap',
#  'Gravity',
#  'Cryin',
#  'The Suburbs',
#  'Twist And Shout',
#  'Live High',
#  'Girl',
#  'Perfect Day',
#  'Shiver',
#  'Hotel California',
#  'Where Is My Mind',
#  'Lyin Eyes',
#  'Dream On',
#  'Bohemian Rhapsody',
#  'She Loves You',
#  'Superheroes',
#  'Wet Sand',
#  'Man In The Mirror',
#  'The Zephyr Song',
#  'Californication',
#  'Patience',
#  'Lithium',
#  'House Of The Rising Sun',
#  'Eternal Flame',
#  'Kickapoo',
#  'Daughters',
#  'Tequila Sunrise',
#  'Shes Electric',
#  'If I Fell',
#  'New Kid In Town',
#  'Dani California',
#  'Seven Nation Army',
#  'While My Guitar Gently Weeps',
#  'No Such Thing',
#  'Head Over Feet',
#  'Dont Speak',
#  'Youve Got A Friend',
#  'My Sweet Lord',
#  'Only Ones Who Know',
#  'Africa',
#  'Still Got The Blues',
#  'Michelle',
#  'Wag Mo Na Sana',
#  'Honey Pie',
#  'We Are The Champions',
#  'Starman',
#  'Black Hole Sun',
#  'Shes Always A Woman',
#  'Heal The World',
#  'About A Girl',
#  'Light My Fire',
#  'At Last',
#  'When The Sun Goes Down',
#  'After Hours',
#  'Dont Stop Me Now',
#  'Here There And Everywhere',
#  'Killer Queen',
#  'Life On Mars',
#  'Roses Are Free',
#  'Soldier Of Fortune',
#  'And I Love Her',
#  'Married With Children']

# %%
# Out:
# ['C',
#  'G',
#  'Am',
#  'F',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'G',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'G',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'F',
#  'G',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'G',
#  'C',
#  'G',
#  'Am',
#  'F',
#  'G',
#  'C']

# %% [markdown]
# Sudo code:
# - Read in each string of chords and clean them
# - Tabulate # of times each chord comes up in a given song
#  1. Take note of each unique chord
#  2. Call np.where for each and store the corresponding indices
#      - This will save time so we don't call np.where for every single chord of every song
# - Row sum and treat the largest row as the key of the song

# %%
a=list(combinations_with_replacement(states, 2))
for i in range(len(a)):
    a[i] = a[i][0] + ',' + a[i][1]

# %%
np.where(np.asarray(states) == 'B')[0][0]
# Out:
# 4

# %%
a
# Out:
# ['A,A',
#  'A,A#',
#  'A,A#m',
#  'A,Am',
#  'A,B',
#  'A,Bm',
#  'A,C',
#  'A,C#',
#  'A,C#m',
#  'A,Cm',
#  'A,D',
#  'A,D#',
#  'A,D#m',
#  'A,Dm',
#  'A,E',
#  'A,Em',
#  'A,F',
#  'A,F#',
#  'A,F#m',
#  'A,Fm',
#  'A,G',
#  'A,G#',
#  'A,G#m',
#  'A,Gm',
#  'A#,A#',
#  'A#,A#m',
#  'A#,Am',
#  'A#,B',
#  'A#,Bm',
#  'A#,C',
#  'A#,C#',
#  'A#,C#m',
#  'A#,Cm',
#  'A#,D',
#  'A#,D#',
#  'A#,D#m',
#  'A#,Dm',
#  'A#,E',
#  'A#,Em',
#  'A#,F',
#  'A#,F#',
#  'A#,F#m',
#  'A#,Fm',
#  'A#,G',
#  'A#,G#',
#  'A#,G#m',
#  'A#,Gm',
#  'A#m,A#m',
#  'A#m,Am',
#  'A#m,B',
#  'A#m,Bm',
#  'A#m,C',
#  'A#m,C#',
#  'A#m,C#m',
#  'A#m,Cm',
#  'A#m,D',
#  'A#m,D#',
#  'A#m,D#m',
#  'A#m,Dm',
#  'A#m,E',
#  'A#m,Em',
#  'A#m,F',
#  'A#m,F#',
#  'A#m,F#m',
#  'A#m,Fm',
#  'A#m,G',
#  'A#m,G#',
#  'A#m,G#m',
#  'A#m,Gm',
#  'Am,Am',
#  'Am,B',
#  'Am,Bm',
#  'Am,C',
#  'Am,C#',
#  'Am,C#m',
#  'Am,Cm',
#  'Am,D',
#  'Am,D#',
#  'Am,D#m',
#  'Am,Dm',
#  'Am,E',
#  'Am,Em',
#  'Am,F',
#  'Am,F#',
#  'Am,F#m',
#  'Am,Fm',
#  'Am,G',
#  'Am,G#',
#  'Am,G#m',
#  'Am,Gm',
#  'B,B',
#  'B,Bm',
#  'B,C',
#  'B,C#',
#  'B,C#m',
#  'B,Cm',
#  'B,D',
#  'B,D#',
#  'B,D#m',
#  'B,Dm',
#  'B,E',
#  'B,Em',
#  'B,F',
#  'B,F#',
#  'B,F#m',
#  'B,Fm',
#  'B,G',
#  'B,G#',
#  'B,G#m',
#  'B,Gm',
#  'Bm,Bm',
#  'Bm,C',
#  'Bm,C#',
#  'Bm,C#m',
#  'Bm,Cm',
#  'Bm,D',
#  'Bm,D#',
#  'Bm,D#m',
#  'Bm,Dm',
#  'Bm,E',
#  'Bm,Em',
#  'Bm,F',
#  'Bm,F#',
#  'Bm,F#m',
#  'Bm,Fm',
#  'Bm,G',
#  'Bm,G#',
#  'Bm,G#m',
#  'Bm,Gm',
#  'C,C',
#  'C,C#',
#  'C,C#m',
#  'C,Cm',
#  'C,D',
#  'C,D#',
#  'C,D#m',
#  'C,Dm',
#  'C,E',
#  'C,Em',
#  'C,F',
#  'C,F#',
#  'C,F#m',
#  'C,Fm',
#  'C,G',
#  'C,G#',
#  'C,G#m',
#  'C,Gm',
#  'C#,C#',
#  'C#,C#m',
#  'C#,Cm',
#  'C#,D',
#  'C#,D#',
#  'C#,D#m',
#  'C#,Dm',
#  'C#,E',
#  'C#,Em',
#  'C#,F',
#  'C#,F#',
#  'C#,F#m',
#  'C#,Fm',
#  'C#,G',
#  'C#,G#',
#  'C#,G#m',
#  'C#,Gm',
#  'C#m,C#m',
#  'C#m,Cm',
#  'C#m,D',
#  'C#m,D#',
#  'C#m,D#m',
#  'C#m,Dm',
#  'C#m,E',
#  'C#m,Em',
#  'C#m,F',
#  'C#m,F#',
#  'C#m,F#m',
#  'C#m,Fm',
#  'C#m,G',
#  'C#m,G#',
#  'C#m,G#m',
#  'C#m,Gm',
#  'Cm,Cm',
#  'Cm,D',
#  'Cm,D#',
#  'Cm,D#m',
#  'Cm,Dm',
#  'Cm,E',
#  'Cm,Em',
#  'Cm,F',
#  'Cm,F#',
#  'Cm,F#m',
#  'Cm,Fm',
#  'Cm,G',
#  'Cm,G#',
#  'Cm,G#m',
#  'Cm,Gm',
#  'D,D',
#  'D,D#',
#  'D,D#m',
#  'D,Dm',
#  'D,E',
#  'D,Em',
#  'D,F',
#  'D,F#',
#  'D,F#m',
#  'D,Fm',
#  'D,G',
#  'D,G#',
#  'D,G#m',
#  'D,Gm',
#  'D#,D#',
#  'D#,D#m',
#  'D#,Dm',
#  'D#,E',
#  'D#,Em',
#  'D#,F',
#  'D#,F#',
#  'D#,F#m',
#  'D#,Fm',
#  'D#,G',
#  'D#,G#',
#  'D#,G#m',
#  'D#,Gm',
#  'D#m,D#m',
#  'D#m,Dm',
#  'D#m,E',
#  'D#m,Em',
#  'D#m,F',
#  'D#m,F#',
#  'D#m,F#m',
#  'D#m,Fm',
#  'D#m,G',
#  'D#m,G#',
#  'D#m,G#m',
#  'D#m,Gm',
#  'Dm,Dm',
#  'Dm,E',
#  'Dm,Em',
#  'Dm,F',
#  'Dm,F#',
#  'Dm,F#m',
#  'Dm,Fm',
#  'Dm,G',
#  'Dm,G#',
#  'Dm,G#m',
#  'Dm,Gm',
#  'E,E',
#  'E,Em',
#  'E,F',
#  'E,F#',
#  'E,F#m',
#  'E,Fm',
#  'E,G',
#  'E,G#',
#  'E,G#m',
#  'E,Gm',
#  'Em,Em',
#  'Em,F',
#  'Em,F#',
#  'Em,F#m',
#  'Em,Fm',
#  'Em,G',
#  'Em,G#',
#  'Em,G#m',
#  'Em,Gm',
#  'F,F',
#  'F,F#',
#  'F,F#m',
#  'F,Fm',
#  'F,G',
#  'F,G#',
#  'F,G#m',
#  'F,Gm',
#  'F#,F#',
#  'F#,F#m',
#  'F#,Fm',
#  'F#,G',
#  'F#,G#',
#  'F#,G#m',
#  'F#,Gm',
#  'F#m,F#m',
#  'F#m,Fm',
#  'F#m,G',
#  'F#m,G#',
#  'F#m,G#m',
#  'F#m,Gm',
#  'Fm,Fm',
#  'Fm,G',
#  'Fm,G#',
#  'Fm,G#m',
#  'Fm,Gm',
#  'G,G',
#  'G,G#',
#  'G,G#m',
#  'G,Gm',
#  'G#,G#',
#  'G#,G#m',
#  'G#,Gm',
#  'G#m,G#m',
#  'G#m,Gm',
#  'Gm,Gm']

# %%
tr = np.asmatrix([[0, 1, 1, 0],
             [1, 4, 1, 0]])

# %%
col_sums = np.sum(tr, axis = 0)

# %%
tr / col_sums
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# matrix([[0. , 0.2, 0.5, nan],
#         [1. , 0.8, 0.5, nan]])

# %%
math.sqrt(0.025)/2
# Out:
# 0.07905694150420949

# %%
a = np.asmatrix([[0,1],
                 [0.25, 0.75]])
b = np.asmatrix([[0.1, 0.9],
                 [0.3, 0.7]])
compute_euclidean(a, b)
# Out:
# 0.0125

# %%
np.sum(np.multiply(a-b, a-b))
# Out:
# 0.025

# %%
np.sum(a-b)
# Out:
# 2.7755575615628914e-17
